# %% [markdown]
# ## Test the USE with a baseline set of questions
# Manually curate a list of questions so that there is a range of minor to larger changes

# %% [markdown]
# ### Import the necessary libraries

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import os
import pandas as pd
import re
import json
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Set the paths and files

# %%
use_path = "dataset/"
baseline_file = "baseline_questions.csv"
quora_file = "quora_questions.csv"

# %% [markdown]
# ### Donload the USE module

# %%
module_url = "https://tfhub.dev/google/universal-sentence-encoder-large/3" 
embed = hub.Module(module_url)

# %% [markdown]
# ### Create an interactive session to use later when running the model

# %%
session = tf.InteractiveSession()
session.run(tf.global_variables_initializer())
session.run(tf.tables_initializer())

# %% [markdown]
# ### Get the list of baseline questions to test

# %%
def get_baseline():
    # Read in the list of qustions from the file
    qs_path = use_path + baseline_file
    base_qs = pd.read_csv(qs_path)
    queries = [q for q in base_qs['Question']]
    return(queries)

# %% [markdown]
# ### Create a dataframe of quora question pairs and answer labels

# %%
def get_quora_qs():
    quora_path = use_path + quora_file
    quora_qs = pd.read_csv(quora_path)
    return(quora_qs)

# %% [markdown]
# ### Get the cosine similarity and use placeholders to feed the queries to the USE

# %%
sts_input1 = tf.placeholder(tf.string, shape=(None))
sts_input2 = tf.placeholder(tf.string, shape=(None))

# For evaluation we use exactly normalized rather than
# approximately normalized.
sts_encode1 = tf.nn.l2_normalize(embed(sts_input1), axis=1)
sts_encode2 = tf.nn.l2_normalize(embed(sts_input2), axis=1)

cosine_similarities = tf.reduce_sum(tf.multiply(sts_encode1, sts_encode2), axis=1)
clip_cosine_similarities = tf.clip_by_value(cosine_similarities, 0.0, 1.0)
sim_scores = 1.0 - tf.divide(tf.acos(clip_cosine_similarities), 3.14)

def get_scores(session, text_a, text_b):
    """Returns the similarity scores"""
    emba, embb, scores= session.run(
        [sts_encode1, sts_encode2, sim_scores],
        feed_dict={
            sts_input1: text_a,
            sts_input2: text_b
        })
    return(emba, embb, scores)

# %% [markdown]
# ### Find the best match using cosine similarity
# Go through each of the baseline questions and find the best match

# %%
quora_df = get_quora_qs()
quora_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   5    11    12  Astrology: I am a Capricorn Sun Cap moon and c...
# 1   7    15    16                     How can I be a good geologist?
# 2  11    23    24        How do I read and find my YouTube comments?
# 3  12    25    26               What can make Physics easy to learn?
# 4  13    27    28        What was your first sexual experience like?
#
#                                            question2  is_duplicate
# 0  I'm a triple Capricorn (Sun, Moon and ascendan...             1
# 1          What should I do to be a great geologist?             1
# 2             How can I see all my Youtube comments?             1
# 3            How can you make physics easy to learn?             1
# 4             What was your first sexual experience?             1

# %%
results = []
    
queries = get_baseline()
examples = [e for e in quora_df['question2']]
for i, q in enumerate(queries):
    emba, embb, scores = get_scores(session, [q], examples)
    quora_df['cosine_score'] = list(scores)
    sort_df = quora_df.sort_values('cosine_score', ascending=False)
    best = sort_df.head(n=1)
    ans = (best['question2']).tolist()[0]
    results.append([q, ans, (best['question1']).tolist()[0], (best['is_duplicate']).tolist()[0],
                    np.round((best['cosine_score']).tolist()[0], 3)])
    if i % 10 == 0:
        print(f"Processed {i} queries")
df = pd.DataFrame(results, columns=['Query', 'Best Match', 'Original', 'Is Duplicate?', 'Similarity'])
# Out:
# Processed 0 queries
# Processed 10 queries
# Processed 20 queries
# Processed 30 queries

# %%
type(scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a1bc8d1366b2> in <module>()
# ----> 1 type(scores)
#
# NameError: name 'scores' is not defined

# %%
display(df.sort_values('Similarity', ascending=False))
# Out:
#                                                 Query  \
# 1                            What is meaning of life?
# 0                            What is purpose of life?
# 22  How many months does it take to gain knowledge...
# 12           How do I use Twitter as a business tool?
# 10         How do I use Twitter as a business source?
# 5                            is What purpose of life?
# 25  How many months does it take to gain knowledge...
# 17      How do you make a screenshot on a Mac laptop?
# 24  How much time does it take to create Android a...
# 23  How many months does it take to develop Androi...
# 16  How do you make a screenshot on a Windows laptop?
# 18             How do you take a screenshot on a Mac?
# 3                            What is porpose of life?
# 14          How do I use Twitter as a busines source?
# 8   is it possible to recover my email if I forgot...
# 26  How many months does it take to gain knowledge...
# 6      Can I recover my email if I lost the password?
# 7     Can I get my email if I misplaced the password?
# 13            can I use Twitter as a business source?
# 27            When is it too late to learn the piano?
# 19      How do you take a bcreenshot on a Mac laptop?
# 9    email my password? Can if the I recover forgot I
# 21      you take on do Mac screenshot a a laptop? How
# 32               Where can I learn to play the piano?
# 28           When is it too late to learn the guitar?
# 15         Twitter do business I source? How a as use
# 20                        screenshot on a Mac laptop?
# 2                      What is purpose of technology?
# 31              When is it too late to learn spanish?
# 33          When is the best time to learn the piano?
# 30                 When is it too late to go to work?
# 11            How do I use my cat as a business tool?
# 4                             What is colour of life?
# 34         When is it too late to learn the moonwalk?
# 29                           Where can I buy a piano?
#
#                                            Best Match  \
# 1                     What's are the meaning of life?
# 0   What's the purpose of life? What is life actua...
# 22  How much time does it take to learn Android ap...
# 12                How can I use Twitter for business?
# 10                How can I use Twitter for business?
# 5   What's the purpose of life? What is life actua...
# 25  How much time does it take to learn Android ap...
# 17  How do I take a screenshot on my MacBook Pro? ...
# 24  How much time does it take to learn Android ap...
# 23  How much time does it take to learn Android ap...
# 16  How do I take a screenshot on my MacBook Pro? ...
# 18  How do I take a screenshot on my MacBook Pro? ...
# 3                  What is the exact meaning of life?
# 14                How can I use Twitter for business?
# 8   I do not remember my password to my Gmail acco...
# 26  How much time does it take to learn Android ap...
# 6   I do not remember my password to my Gmail acco...
# 7   I do not remember my password to my Gmail acco...
# 13                How can I use Twitter for business?
# 27  I'm almost 40. Is it too late for me to learn ...
# 19  How do I take a screenshot on my MacBook Pro? ...
# 9   I can't remember my Gmail password or my recov...
# 21  How do I take a screenshot on my MacBook Pro? ...
# 32           I want to learn singing. How do I start?
# 28  I'm almost 40. Is it too late for me to learn ...
# 15                How can I use Twitter for business?
# 20  How do I take a screenshot on my MacBook Pro? ...
# 2   What's the purpose of life? What is life actua...
# 31         How can I learn to speak English fluently?
# 33  I'm almost 40. Is it too late for me to learn ...
# 30            When will the best time for having sex?
# 11             How do I create an e-commerce website?
# 4                     What's are the meaning of life?
# 34  I'm almost 40. Is it too late for me to learn ...
# 29  How difficult would it be to learn how to play...
#
#                                              Original  Is Duplicate?  \
# 1                  What the meaning of this all life?              1
# 0                            What is purpose of life?              1
# 22  How many months does it take to gain knowledge...              1
# 12         How do I use Twitter as a business source?              1
# 10         How do I use Twitter as a business source?              1
# 5                            What is purpose of life?              1
# 25  How many months does it take to gain knowledge...              1
# 17      How do you take a screenshot on a Mac laptop?              1
# 24  How many months does it take to gain knowledge...              1
# 23  How many months does it take to gain knowledge...              1
# 16      How do you take a screenshot on a Mac laptop?              1
# 18      How do you take a screenshot on a Mac laptop?              1
# 3            What is the meaning and purpose to life?              1
# 14         How do I use Twitter as a business source?              1
# 8            How can you recover your Gmail password?              1
# 26  How many months does it take to gain knowledge...              1
# 6            How can you recover your Gmail password?              1
# 7            How can you recover your Gmail password?              1
# 13         How do I use Twitter as a business source?              1
# 27            When is it too late to learn the piano?              1
# 19      How do you take a screenshot on a Mac laptop?              1
# 9   I was suddenly logged off Gmail. I can't remem...              1
# 21      How do you take a screenshot on a Mac laptop?              1
# 32                        How do I learn how to sing?              1
# 28            When is it too late to learn the piano?              1
# 15         How do I use Twitter as a business source?              1
# 20      How do you take a screenshot on a Mac laptop?              1
# 2                            What is purpose of life?              1
# 31                  How I can speak English fluently?              1
# 33            When is it too late to learn the piano?              1
# 30                  What’s the best time to have sex?              1
# 11         How would I develop an e-commerce website?              1
# 4                  What the meaning of this all life?              1
# 34            When is it too late to learn the piano?              1
# 29  What is the best accordion for beginners to le...              0
#
#     Similarity
# 1        0.944
# 0        0.929
# 22       0.912
# 12       0.905
# 10       0.903
# 5        0.897
# 25       0.896
# 17       0.888
# 24       0.886
# 23       0.881
# 16       0.880
# 18       0.872
# 3        0.868
# 14       0.861
# 8        0.858
# 26       0.851
# 6        0.848
# 7        0.825
# 13       0.821
# 27       0.817
# 19       0.802
# 9        0.799
# 21       0.797
# 32       0.777
# 28       0.767
# 15       0.766
# 20       0.764
# 2        0.754
# 31       0.749
# 33       0.746
# 30       0.715
# 11       0.712
# 4        0.701
# 34       0.701
# 29       0.694

# %% [markdown]
# ### Write the output to a CSV file

# %%
df.to_csv('baseline_quora_test.csv')
